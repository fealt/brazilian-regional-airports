# %%
# loading libraries

import os
import time

import folium
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import scipy
import seaborn as sns
from IPython.display import display_html
from scipy.cluster import hierarchy
from scipy.cluster.hierarchy import dendrogram
from sklearn.cluster import AgglomerativeClustering, KMeans
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
pd.set_option("display.max_columns", None)

# %%
flights_csv = [x for x in os.listdir("./assets/csv/") if x.startswith("flights_")]

# %%
flights_csv.sort()

# %%
# function to load files

# %% [raw]
# def load_files(file):
#     year = file[8:12]
#     df = pd.read_csv(f"./assets/csv/{file}", sep=",")
#     df = df[["icao_origin", "available_seat_km", "revenue_pax_km"]]
#     df = df.groupby("icao_origin").sum().reset_index()
#     df["available_seat_km"] = df["available_seat_km"].astype(float)
#     df["revenue_pax_km"] = df["revenue_pax_km"].astype(float)
#     df["year"] = year
#     df.to_csv(f"./assets/csv/cluster/cluster_{year}.csv", sep=",", index=False)
#     return df

# %% [raw]
# # clustering for 2002-2007 – DELETE ME LATER
#
# flights_csv[:6]
#
# df_x = []
#
# for x in flights_csv[:6]:
#     print(x)
#     temp = load_files(x)
#     df_x.append(temp)
#
# df_cluster = pd.concat(df_x)

# %% [raw]
# df_x = []
#
# for x in flights_csv:
#     print(x)
#     temp = load_files(x)
#     df_x.append(temp)
#
# df_cluster = pd.concat(df_x)

# %% [raw]
# df_cluster.to_csv('./assets/csv/cluster/df_cluster_all_years.csv', sep=',')

# %%
df_cluster = pd.read_csv("./assets/csv/cluster/df_cluster_all_years.csv", sep=",").drop(
    columns=["Unnamed: 0", "year"]
)

# %%
df_cluster = df_cluster.groupby(by="icao_origin").sum().reset_index()
df_cluster
# Out:
#     icao_origin  available_seat_km  revenue_pax_km
# 0          SBAA       3.749310e+05    2.214450e+05
# 1          SBAC       5.359546e+06    2.740547e+06
# 2          SBAE       2.258232e+08    1.462803e+08
# 3          SBAQ       5.299803e+06    3.096486e+06
# 4          SBAR       9.655877e+09    7.409398e+09
# ..          ...                ...             ...
# 241        SWRD       5.834006e+07    4.388815e+07
# 242        SWSI       4.755653e+08    3.630672e+08
# 243        SWTP       1.751399e+06    8.988330e+05
# 244        SWTS       1.262871e+06    5.194930e+05
# 245        SWVC       9.018900e+04    5.553200e+04
#
# [246 rows x 3 columns]

# %%
# function for count

# %% [raw]
# def load_files_count(file):
#     year = file[8:12]
#     df = pd.read_csv(f"./assets/csv/{file}", sep=",")
#     df = df[["icao_origin"]].value_counts()
#     df = df.reset_index()
#     df.columns = ["icao_code", "count"]
#     df.to_csv(f"./assets/csv/count/df{year}.csv", sep=",", index=False)
#     return df

# %% [raw]
# df_y = []
#
# for y in flights_csv:
#     temp = load_files_count(y)
#     df_y.append(temp)
#
# df_count = pd.concat(df_y)

# %% [raw]
# df_count.to_csv('./assets/csv/count/df_count_all_years.csv', sep=',')

# %%
df_count = pd.read_csv("./assets/csv/count/df_count_all_years.csv", sep=",").drop(
    columns="Unnamed: 0"
)

# %%
df_count = (
    df_count.groupby("icao_code")
    .sum()
    .sort_values(by="count", ascending=False)
    .reset_index()
)

# %%
df_count
# Out:
#     icao_code   count
# 0        SBGR  818607
# 1        SBSP  794108
# 2        SBBR  732100
# 3        SBKP  554891
# 4        SBGL  520716
# ..        ...     ...
# 241      SNPY       1
# 242      SNFO       1
# 243      SBMT       1
# 244      SNXB       1
# 245      SBUY       1
#
# [246 rows x 2 columns]

# %%
# duplicated airports

# %%
same_airport = {
    "SJTC": "SBAE",
    "SBRG": "SJRG",
    "SBCM": "SSIM",
    "SBNT": "SBSG",
    "SBFE": "SDIY",
    "SWRD": "SBRD",
    "SSZW": "SBPG",
    "SSPB": "SBPO",
    "SWSI": "SBSI",
    "SBQV": "SBVC",
    "SBBT": "SNBA",
    "SBGU": "SSGG",
    "SBMH": "SBMG",
    "SBPM": "SBPJ",
    "SNDM": "SBLE",
    "SBMC": "SWIQ",
}

# %%
df_cluster["icao_origin"] = df_cluster["icao_origin"].replace(same_airport)

# %% [raw]
# df_cluster['icao'] = df_cluster['icao_origin'].apply(lambda x: same_airport[x])

# %%
df_cluster = df_cluster.groupby(by="icao_origin").sum().reset_index()

# %%
df_cluster = df_cluster.drop(
    df_cluster.index[
        df_cluster["icao_origin"].isin(
            ["SBGS", "SBMT", "SWLF", "SNXB", "SBMM", "SNFO", "SBMN", "SNPY", "SNFE"]
        )
    ],
    axis=0,
)

# %%
df_cluster
# Out:
#     icao_origin  available_seat_km  revenue_pax_km
# 0          SBAA       3.749310e+05    2.214450e+05
# 1          SBAC       5.359546e+06    2.740547e+06
# 2          SBAE       2.503321e+08    1.587877e+08
# 3          SBAQ       5.299803e+06    3.096486e+06
# 4          SBAR       9.655877e+09    7.409398e+09
# ..          ...                ...             ...
# 230        SWPI       9.602442e+07    6.304970e+07
# 231        SWPY       8.839800e+04    3.942500e+04
# 232        SWTP       1.751399e+06    8.988330e+05
# 233        SWTS       1.262871e+06    5.194930e+05
# 234        SWVC       9.018900e+04    5.553200e+04
#
# [226 rows x 3 columns]

# %%
df_count["icao_code"] = df_count["icao_code"].replace(same_airport)

# %%
df_count = df_count.groupby(by="icao_code").sum().reset_index()

# %%
df_count = df_count.sort_values(by="count", ascending=False)

# %%
df_count = df_count.drop(
    df_count.index[
        df_count["icao_code"].isin(
            ["SBGS", "SBMT", "SWLF", "SNXB", "SBMM", "SNFO", "SBMN", "SNPY", "SNFE"]
        )
    ],
    axis=0,
)

# %%
df_count
# Out:
#     icao_code   count
# 39       SBGR  818607
# 100      SBSP  794108
# 11       SBBR  732100
# 58       SBKP  554891
# 37       SBGL  520716
# ..        ...     ...
# 196      SSLT       5
# 135      SILC       4
# 137      SIZX       4
# 197      SSOE       3
# 116      SBUY       1
#
# [226 rows x 2 columns]

# %%
# export to csv

# %%
df_cluster.to_csv("./assets/csv/temp/df_cluster.csv", sep=",")

# %%
df_count.to_csv("./assets/csv/temp/df_count.csv", sep=",")

# %% [raw]
# # Python code t get difference of two lists
# # Using set()
# def Diff(li1, li2):
#     return list(set(li1) - set(li2)) + list(set(li2) - set(li1))
#
# new = Diff(li1, li2)

# %% [markdown]
# # Clustering

# %%
# reference

# https://www.kaggle.com/lucaspcarlini/clustering-and-visualisation-using-folium-maps

# %%
# clustering flights from 2002 to 2021

# %%
flights_all = df_cluster.copy()

# %% [markdown]
# ## Dendorgram

# %%
flights_all_dend = df_cluster.copy().drop(columns=["icao_origin"])

# %%
flights_all_dend
# Out:
#      available_seat_km  revenue_pax_km
# 0         3.749310e+05    2.214450e+05
# 1         5.359546e+06    2.740547e+06
# 2         2.503321e+08    1.587877e+08
# 3         5.299803e+06    3.096486e+06
# 4         9.655877e+09    7.409398e+09
# ..                 ...             ...
# 230       9.602442e+07    6.304970e+07
# 231       8.839800e+04    3.942500e+04
# 232       1.751399e+06    8.988330e+05
# 233       1.262871e+06    5.194930e+05
# 234       9.018900e+04    5.553200e+04
#
# [226 rows x 2 columns]

# %%
plt.figure(figsize=(20, 6))

X = flights_all_dend
X.shape

dendrogram = hierarchy.dendrogram(
    hierarchy.linkage(StandardScaler().fit_transform(X), method="ward"),
    color_threshold=6,
)

# %time
# Out:
# CPU times: user 3 µs, sys: 1e+03 ns, total: 4 µs
# Wall time: 2.86 µs

# %% [markdown]
# > Although the dendorgram indicated we could go ahead with three clusters, the case with four clusters makes sense too. Therefore, an additional check of visualizing the data may be performed before deciding on the number of clusters.

# %% [markdown]
# - x axis represents individual points
# - y axis represents the distance or dissimilarity between clusters
#
# - each inverted U represents a cluster divided into its two child clusters
# - the width of the U shape represents the distance between the two child clusters
# - a wider U, therefore, means that the two child clusters were farther away from each other as compared to a narrower U in the diagram
#
# - drawing a horizontal line at any part of the figure, the number of vertical lines it intersects tells the number of clusters at that stage, and the distance between those vertical lines indicates the inter-cluster distance
# - REWRITE it seems that the top three clusters have the highest distances between them

# %% [markdown]
# ## Clustering Distortion, the Elbow Method
#
# - Definition: mean sum of squared distances to centers

# %%
codes = flights_all[["icao_origin"]]
flights_all.drop("icao_origin", axis=1, inplace=True)

# %% [raw]
# scaler = StandardScaler()
# scaler.fit(flights_all)
#
# X_std = scaler.transform(flights_all)

# %% [raw]
# distortions = []
#
# for n_clusters in range(2,14):
#     kmeans = KMeans(n_clusters)
#     kmeans.fit(X_std)
#     distortions.append(kmeans.inertia_)

# %%
distortions = []

K = range(2, 14)
for k in K:
    kmean = KMeans(n_clusters=k, random_state=0, n_init=50, max_iter=500)
    kmean.fit(flights_all)
    distortions.append(kmean.inertia_)

# %%
fig, ax = plt.subplots(figsize=(10, 5))

ax.plot(range(2, 14), distortions, "-o", color="tomato")

plt.xlabel("n clusters (k)")
plt.ylabel("Distortion")
plt.title("The Elbow Method");

# %% [markdown]
# - distortion decreases sharply from 1 to 3 clusters
# - after 6 clusters, gradual decrease with a subsequent increase in number of clusters
# - the ideal number of clusters here is therefore, 4
#
# > the elbow method only gives an indication of ideal number of clusters. Occasionally, it may be insufficient to find an optimal k. For instance, the elbow method fails when data is evenly distributed.
# > There are other methods to find the optimal number of clusters such as the average silhouette and gap statistic methods. They are indicative methods too, and will not be discussed as a part of this course.

# %% [markdown]
# ## K-means with 5 clusters

# %%
# run k-means clustering
kmeans = KMeans(n_clusters=5, random_state=0).fit(flights_all)

codes["cluster"] = kmeans.labels_

# %%
pca = PCA().fit(flights_all)
pca_types = pca.transform(flights_all)
print("Variance explained by each component (%): ")
for i in range(len(pca.explained_variance_ratio_)):
    print("\n", i + 1, "º:", pca.explained_variance_ratio_[i] * 100)
print("Total sum (%): ", sum(pca.explained_variance_ratio_) * 100)
print(
    "Explained variance of the first two components (%): ",
    sum(pca.explained_variance_ratio_[0:1]) * 100,
)
# Out:
# Variance explained by each component (%):
#
#  1 º: 99.97375533973786
#
#  2 º: 0.026244660262144812
# Total sum (%):  100.0
# Explained variance of the first two components (%):  99.97375533973786

# %%
c0 = []
c1 = []
c2 = []
c3 = []
c4 = []

for i in range(len(pca_types)):
    if kmeans.labels_[i] == 0:
        c0.append(pca_types[i])
    if kmeans.labels_[i] == 1:
        c1.append(pca_types[i])
    if kmeans.labels_[i] == 2:
        c2.append(pca_types[i])
    if kmeans.labels_[i] == 3:
        c3.append(pca_types[i])
    if kmeans.labels_[i] == 4:
        c4.append(pca_types[i])

c0 = np.array(c0)
c1 = np.array(c1)
c2 = np.array(c2)
c3 = np.array(c3)
c4 = np.array(c4)

plt.figure(figsize=(7, 7))
plt.scatter(c0[:, 0], c0[:, 1], c="r", label="Cluster 0")
plt.scatter(c1[:, 0], c1[:, 1], c="g", label="Cluster 1")
plt.scatter(c2[:, 0], c2[:, 1], c="b", label="Cluster 2")
plt.scatter(c3[:, 0], c3[:, 1], c="c", label="Cluster 3")
plt.scatter(c4[:, 0], c4[:, 1], c="m", label="Cluster 4")

plt.legend()
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.title("Low dimensional visualization (PCA) - All Airports");

# %% [raw]
# c0 = []
# c1 = []
# c2 = []
# c3 = []
# c4 = []
# c5 = []
# c6 = []
# c7 = []
#
# for i in range(len(pca_types)):
#     if kmeans.labels_[i] == 0:
#         c0.append(pca_types[i])
#     if kmeans.labels_[i] == 1:
#         c1.append(pca_types[i])
#     if kmeans.labels_[i] == 2:
#         c2.append(pca_types[i])
#     if kmeans.labels_[i] == 3:
#         c3.append(pca_types[i])
#     if kmeans.labels_[i] == 4:
#         c4.append(pca_types[i])
#     if kmeans.labels_[i] == 5:
#         c5.append(pca_types[i])
#     if kmeans.labels_[i] == 6:
#         c6.append(pca_types[i])
#     if kmeans.labels_[i] == 7:
#         c7.append(pca_types[i])
#
#
# c0 = np.array(c0)
# c1 = np.array(c1)
# c2 = np.array(c2)
# c3 = np.array(c3)
# c4 = np.array(c4)
# c5 = np.array(c5)
# c6 = np.array(c6)
# c7 = np.array(c7)
#
# plt.figure(figsize=(7, 7))
# plt.scatter(c0[:, 0], c0[:, 1], c="r", label="Cluster 0")
# plt.scatter(c1[:, 0], c1[:, 1], c="g", label="Cluster 1")
# plt.scatter(c2[:, 0], c2[:, 1], c="b", label="Cluster 2")
# plt.scatter(c3[:, 0], c3[:, 1], c="tab:orange", label="Cluster 3")
# plt.scatter(c4[:, 0], c4[:, 1], c="c", label="Cluster 4")
# plt.scatter(c5[:, 0], c5[:, 1], c="m", label="Cluster 5")
# plt.scatter(c6[:, 0], c6[:, 1], c="y", label="Cluster 6")
# plt.scatter(c7[:, 0], c7[:, 1], c="k", label="Cluster 7")
# plt.legend()
# plt.xlabel("PC1")
# plt.ylabel("PC2")
# plt.title("Low dimensional visualization (PCA) - Airports");

# %%
flights_all["cluster"] = kmeans.labels_

flights_all
# Out:
#      available_seat_km  revenue_pax_km  cluster
# 0         3.749310e+05    2.214450e+05        0
# 1         5.359546e+06    2.740547e+06        0
# 2         2.503321e+08    1.587877e+08        0
# 3         5.299803e+06    3.096486e+06        0
# 4         9.655877e+09    7.409398e+09        3
# ..                 ...             ...      ...
# 230       9.602442e+07    6.304970e+07        0
# 231       8.839800e+04    3.942500e+04        0
# 232       1.751399e+06    8.988330e+05        0
# 233       1.262871e+06    5.194930e+05        0
# 234       9.018900e+04    5.553200e+04        0
#
# [226 rows x 3 columns]

# %%
flights_all.groupby("cluster").mean()
# Out:
#          available_seat_km  revenue_pax_km
# cluster
# 0             3.672273e+08    2.689577e+08
# 1             7.174532e+10    5.434936e+10
# 2             1.441609e+11    1.106443e+11
# 3             1.448259e+10    1.088226e+10
# 4             3.956415e+10    2.956701e+10

# %%
sns.catplot(x="cluster", y="revenue_pax_km", data=flights_all, kind="bar");

# %%
sns.catplot(x="cluster", y="available_seat_km", data=flights_all, kind="bar");

# %%
airports_br = pd.read_csv("./assets/csv/airports_brazil.csv", sep=",")

# %%
airports = airports_br[
    ["icao_code", "icao_code_old", "lat_dd", "long_dd", "city_primary", "state"]
]
airports
# Out:
#     icao_code icao_code_old     lat_dd    long_dd               city_primary  \
# 0        SBAA           NaN  -8.348611 -49.303056      Conceição do araguaia
# 1        SBAC           NaN  -4.568611 -37.804722                    Aracati
# 2        SBAE          SJTC -22.157778 -49.068333                    Arealva
# 3        SBAQ           NaN -21.804444 -48.140278                 Araraquara
# 4        SBAR           NaN -10.985278 -37.073333                    Aracaju
# ..        ...           ...        ...        ...                        ...
# 227      SWPI           NaN  -2.669444 -56.771111                  Parintins
# 228      SWPY           NaN -15.565556 -54.337778         Primavera do leste
# 229      SWTP           NaN  -0.416944 -65.033889  Santa isabel do rio negro
# 230      SWTS           NaN -14.661944 -57.443889           Tangará da serra
# 231      SWVC           NaN  -9.981111 -51.140556                  Vila rica
#
#     state
# 0      PA
# 1      CE
# 2      SP
# 3      SP
# 4      SE
# ..    ...
# 227    AM
# 228    MT
# 229    AM
# 230    MT
# 231    MT
#
# [232 rows x 6 columns]

# %%
df_count = df_count.merge(airports)

# %%
df_count = df_count.merge(codes, left_on="icao_code", right_on="icao_origin")

# %%
df_count
# Out:
#     icao_code   count icao_code_old     lat_dd    long_dd  \
# 0        SBGR  818607           NaN -23.435556 -46.473056
# 1        SBSP  794108           NaN -23.626111 -46.656389
# 2        SBBR  732100           NaN -15.871111 -47.918611
# 3        SBKP  554891           NaN -23.006944 -47.134444
# 4        SBGL  520716           NaN -22.810000 -43.250556
# ..        ...     ...           ...        ...        ...
# 221      SSLT       5           NaN -29.812500 -55.893333
# 222      SILC       4           NaN -13.037778 -55.950278
# 223      SIZX       4           NaN -11.296667 -57.548889
# 224      SSOE       3           NaN -26.781111 -53.503333
# 225      SBUY       1           NaN  -4.883056 -65.355833
#
#             city_primary state icao_origin  cluster
# 0              Guarulhos    SP        SBGR        2
# 1              São paulo    SP        SBSP        1
# 2               Brasília    DF        SBBR        2
# 3               Campinas    SP        SBKP        4
# 4         Rio de janeiro    RJ        SBGL        1
# ..                   ...   ...         ...      ...
# 221             Alegrete    RS        SSLT        0
# 222   Lucas do rio verde    MT        SILC        0
# 223                Juara    MT        SIZX        0
# 224  São miguel do oeste    SC        SSOE        0
# 225                Coari    AM        SBUY        0
#
# [226 rows x 9 columns]

# %%
df_count["cluster"].value_counts()
# Out:
# 0    199
# 3     14
# 4      6
# 1      5
# 2      2
# Name: cluster, dtype: int64

# %%
# export to csv

# %% [raw]
# df_count.to_csv("./assets/csv/clusters_1_5.csv", sep=",")

# %%
flights_by_dest = (
    df_count[["icao_code", "city_primary", "state", "cluster"]]
    .sort_values("cluster", ascending=False)
    .reset_index()
    .drop(columns="index")
)

# %%
df1_styler = (
    flights_by_dest[flights_by_dest["cluster"] == 0]
    .sort_values("city_primary", ascending=True)
    .style.set_table_attributes("style='display:inline'")
    .set_caption("Cluster 0")
)
df2_styler = (
    flights_by_dest[flights_by_dest["cluster"] == 1]
    .sort_values("city_primary", ascending=True)
    .style.set_table_attributes("style='display:inline'")
    .set_caption("Cluster 1")
)
df3_styler = (
    flights_by_dest[flights_by_dest["cluster"] == 2]
    .sort_values("city_primary", ascending=True)
    .style.set_table_attributes("style='display:inline'")
    .set_caption("Cluster 2")
)
df4_styler = (
    flights_by_dest[flights_by_dest["cluster"] == 3]
    .sort_values("city_primary", ascending=True)
    .style.set_table_attributes("style='display:inline'")
    .set_caption("Cluster 3")
)
df5_styler = (
    flights_by_dest[flights_by_dest["cluster"] == 4]
    .sort_values("city_primary", ascending=True)
    .style.set_table_attributes("style='display:inline'")
    .set_caption("Cluster 4")
)

# df6_styler = (
#     flights_by_dest[flights_by_dest["cluster"] == 2]
#     .sort_values("city_primary", ascending=True)
#     .style.set_table_attributes("style='display:inline'")
#     .set_caption("Cluster 2")
# )
# df7_styler = (
#     flights_by_dest[flights_by_dest["cluster"] == 1]
#     .sort_values("city_primary", ascending=True)
#     .style.set_table_attributes("style='display:inline'")
#     .set_caption("Cluster 1")
# )
# df8_styler = (
#     flights_by_dest[flights_by_dest["cluster"] == 0]
#     .sort_values("city_primary", ascending=True)
#     .style.set_table_attributes("style='display:inline'")
#     .set_caption("Cluster 0")
# )
# df9_styler = (
#     flights_by_dest[flights_by_dest["cluster"] == 0].loc[0:35, :]
#     .sort_values("city_primary", ascending=True)
#     .style.set_table_attributes("style='display:inline'")
#     .set_caption("Cluster 0")
# )
# df10_styler = (
#     flights_by_dest[flights_by_dest["cluster"] == 0].loc[0:35, :]
#     .sort_values("city_primary", ascending=True)
#     .style.set_table_attributes("style='display:inline'")
#     .set_caption("Cluster 0")
# )
# df11_styler = (
#     flights_by_dest[flights_by_dest["cluster"] == 0].loc[0:35, :]
#     .sort_values("city_primary", ascending=True)
#     .style.set_table_attributes("style='display:inline'")
#     .set_caption("Cluster 0")
# )

space = "\xa0" * 5
display_html(
    df1_styler._repr_html_()
    + space
    + df2_styler._repr_html_()
    + space
    + df3_styler._repr_html_()
    + space
    + df4_styler._repr_html_()
    + space
    + df5_styler._repr_html_(),
    #     + space
    #     + df6_styler._repr_html_()
    #     + space
    #     + df7_styler._repr_html_()
    #     + space
    #     + df8_styler._repr_html_()
    #     + space
    #     + df9_styler._repr_html_()
    #     + space
    #     + df10_styler._repr_html_()
    #     + space
    #     + df11_styler._repr_html_(),
    raw=True,
)
# Out:
# <style  type="text/css" >
# </style><table id="T_6e9f1_" style='display:inline'><caption>Cluster 0</caption><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >icao_code</th>        <th class="col_heading level0 col1" >city_primary</th>        <th class="col_heading level0 col2" >state</th>        <th class="col_heading level0 col3" >cluster</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6e9f1_level0_row0" class="row_heading level0 row0" >96</th>
#                         <td id="T_6e9f1_row0_col0" class="data row0 col0" >SSLT</td>
#                         <td id="T_6e9f1_row0_col1" class="data row0 col1" >Alegrete</td>
#                         <td id="T_6e9f1_row0_col2" class="data row0 col2" >RS</td>
#                         <td id="T_6e9f1_row0_col3" class="data row0 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row1" class="row_heading level0 row1" >109</th>
#                         <td id="T_6e9f1_row1_col0" class="data row1 col0" >SDWQ</td>
#                         <td id="T_6e9f1_row1_col1" class="data row1 col1" >Alenquer</td>
#                         <td id="T_6e9f1_row1_col2" class="data row1 col2" >PA</td>
#                         <td id="T_6e9f1_row1_col3" class="data row1 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row2" class="row_heading level0 row2" >59</th>
#                         <td id="T_6e9f1_row2_col0" class="data row2 col0" >SNYA</td>
#                         <td id="T_6e9f1_row2_col1" class="data row2 col1" >Almeirim</td>
#                         <td id="T_6e9f1_row2_col2" class="data row2 col2" >PA</td>
#                         <td id="T_6e9f1_row2_col3" class="data row2 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row3" class="row_heading level0 row3" >219</th>
#                         <td id="T_6e9f1_row3_col0" class="data row3 col0" >SBMD</td>
#                         <td id="T_6e9f1_row3_col1" class="data row3 col1" >Almeirim</td>
#                         <td id="T_6e9f1_row3_col2" class="data row3 col2" >PA</td>
#                         <td id="T_6e9f1_row3_col3" class="data row3 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row4" class="row_heading level0 row4" >74</th>
#                         <td id="T_6e9f1_row4_col0" class="data row4 col0" >SNAR</td>
#                         <td id="T_6e9f1_row4_col1" class="data row4 col1" >Almenara</td>
#                         <td id="T_6e9f1_row4_col2" class="data row4 col2" >MG</td>
#                         <td id="T_6e9f1_row4_col3" class="data row4 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row5" class="row_heading level0 row5" >205</th>
#                         <td id="T_6e9f1_row5_col0" class="data row5 col0" >SBAT</td>
#                         <td id="T_6e9f1_row5_col1" class="data row5 col1" >Alta floresta</td>
#                         <td id="T_6e9f1_row5_col2" class="data row5 col2" >MT</td>
#                         <td id="T_6e9f1_row5_col3" class="data row5 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row6" class="row_heading level0 row6" >150</th>
#                         <td id="T_6e9f1_row6_col0" class="data row6 col0" >SBHT</td>
#                         <td id="T_6e9f1_row6_col1" class="data row6 col1" >Altamira</td>
#                         <td id="T_6e9f1_row6_col2" class="data row6 col2" >PA</td>
#                         <td id="T_6e9f1_row6_col3" class="data row6 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row7" class="row_heading level0 row7" >108</th>
#                         <td id="T_6e9f1_row7_col0" class="data row7 col0" >SDAG</td>
#                         <td id="T_6e9f1_row7_col1" class="data row7 col1" >Angra dos reis</td>
#                         <td id="T_6e9f1_row7_col2" class="data row7 col2" >RJ</td>
#                         <td id="T_6e9f1_row7_col3" class="data row7 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row8" class="row_heading level0 row8" >119</th>
#                         <td id="T_6e9f1_row8_col0" class="data row8 col0" >SBAC</td>
#                         <td id="T_6e9f1_row8_col1" class="data row8 col1" >Aracati</td>
#                         <td id="T_6e9f1_row8_col2" class="data row8 col2" >CE</td>
#                         <td id="T_6e9f1_row8_col3" class="data row8 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row9" class="row_heading level0 row9" >32</th>
#                         <td id="T_6e9f1_row9_col0" class="data row9 col0" >SNAT</td>
#                         <td id="T_6e9f1_row9_col1" class="data row9 col1" >Aracati</td>
#                         <td id="T_6e9f1_row9_col2" class="data row9 col2" >CE</td>
#                         <td id="T_6e9f1_row9_col3" class="data row9 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row10" class="row_heading level0 row10" >141</th>
#                         <td id="T_6e9f1_row10_col0" class="data row10 col0" >SWGN</td>
#                         <td id="T_6e9f1_row10_col1" class="data row10 col1" >Araguaína</td>
#                         <td id="T_6e9f1_row10_col2" class="data row10 col2" >TO</td>
#                         <td id="T_6e9f1_row10_col3" class="data row10 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row11" class="row_heading level0 row11" >115</th>
#                         <td id="T_6e9f1_row11_col0" class="data row11 col0" >SSOG</td>
#                         <td id="T_6e9f1_row11_col1" class="data row11 col1" >Arapongas</td>
#                         <td id="T_6e9f1_row11_col2" class="data row11 col2" >PR</td>
#                         <td id="T_6e9f1_row11_col3" class="data row11 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row12" class="row_heading level0 row12" >53</th>
#                         <td id="T_6e9f1_row12_col0" class="data row12 col0" >SBAQ</td>
#                         <td id="T_6e9f1_row12_col1" class="data row12 col1" >Araraquara</td>
#                         <td id="T_6e9f1_row12_col2" class="data row12 col2" >SP</td>
#                         <td id="T_6e9f1_row12_col3" class="data row12 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row13" class="row_heading level0 row13" >218</th>
#                         <td id="T_6e9f1_row13_col0" class="data row13 col0" >SBAX</td>
#                         <td id="T_6e9f1_row13_col1" class="data row13 col1" >Araxá</td>
#                         <td id="T_6e9f1_row13_col2" class="data row13 col2" >MG</td>
#                         <td id="T_6e9f1_row13_col3" class="data row13 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row14" class="row_heading level0 row14" >134</th>
#                         <td id="T_6e9f1_row14_col0" class="data row14 col0" >SBAU</td>
#                         <td id="T_6e9f1_row14_col1" class="data row14 col1" >Araçatuba</td>
#                         <td id="T_6e9f1_row14_col2" class="data row14 col2" >SP</td>
#                         <td id="T_6e9f1_row14_col3" class="data row14 col3" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_6e9f1_level0_row15" class="row_heading level0 row15" >35</th>
#                         <td id="T_6e9f1_row15_col0" class="data row15 col0" >SNUI</td>
#                         <td id="T_6e9f1_row15_col1" class="data row15 col1" >Araçuaí</td>
#                         <td id="T_6e9f1_row15_col2" class="data row15 col2" >MG</td>
#                         <td id="T_6e9f1_row15_col3" class="data row15 col3" >0</td>
#             </tr>

# %%
map_clusters = folium.Map(location=[-15, -55], zoom_start=4.5)

# set color scheme for the clusters
x = np.arange(5)
ys = [i + x + (i * x) ** 2 for i in range(5)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lng, cluster, city, state in zip(
    df_count["lat_dd"],
    df_count["long_dd"],
    df_count["cluster"],
    df_count["city_primary"],
    df_count["state"],
):
    # label = folium.Popup(str(city)+ ','+str(state) + '- Cluster ' + str(cluster), parse_html=True)
    folium.vector_layers.CircleMarker(
        [lat, lng],
        radius=5,
        # popup=label,
        tooltip=str(city) + ", " + str(state) + " – Cluster " + str(cluster),
        color=rainbow[cluster - 1],
        fill=True,
        fill_color=rainbow[cluster - 1],
        fill_opacity=0.9,
    ).add_to(map_clusters)

map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_b5919f730c0b4186809882649777f424%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_b5919f730c0b4186809882649777f424%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_b5919f730c0b4186809882649777f424%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_b5919f730c0b4186809882649777f424%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B-15.0%2C%20-55.0%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# ## Agglomerative Clustering

# %%
hierarchical = AgglomerativeClustering(n_clusters=5)
hierarchical.fit(flights_all)

plt.scatter(
    flights_all.iloc[:, 0], codes.iloc[:, 1], c=hierarchical.labels_, cmap="tab10"
)
plt.xlabel(flights_all.columns[0])
plt.ylabel(flights_all.columns[1])
plt.colorbar();

# %% [markdown]
# ## Silhouette
#
# https://www.scikit-yb.org/en/latest/api/cluster/silhouette.html
#
#
# The silhouette value is a measure of how similar an object is to its own cluster compared to other clusters.
#
# To calculate the Silhouette score for each observation/data point, the following distances need to be found out for each observations belonging to all the clusters:
#
# * Mean distance between the observation and all other data points in the same cluster. This distance can also be called a mean intra-cluster distance. The mean distance is denoted by a
# * Mean distance between the observation and all other data points of the next nearest cluster. This distance can also be called a mean nearest-cluster distance. The mean distance is denoted by b
#
# Silhouette score, S, for each sample is calculated using the following formula:
#
# $$S = \frac{(b - a)}{max(a, b)}$$
#
# The value of the Silhouette score varies from -1 to 1. If the score is 1, the cluster is dense and well-separated than other clusters. A value near 0 represents overlapping clusters with samples very close to the decision boundary of the neighboring clusters. A negative score [-1, 0] indicates that the samples might have got assigned to the wrong clusters.
#
# https://dzone.com/articles/kmeans-silhouette-score-explained-with-python-exam

# %% [markdown]
# https://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html

# %%
scaler = StandardScaler()
scaler.fit(flights_all)

X_std = scaler.transform(flights_all)

# %%
from yellowbrick.cluster import SilhouetteVisualizer

# %%
model = KMeans(5).fit(X_std)
visualizer = SilhouetteVisualizer(model, colors="yellowbrick")
visualizer.fit(X_std)  # Fit the data to the visualizer
visualizer.show()
# Finalize and render the figure

# %%
model = KMeans(8).fit(X_std)
visualizer = SilhouetteVisualizer(model, colors="yellowbrick")
visualizer.fit(X_std)  # Fit the data to the visualizer
visualizer.show()
# Finalize and render the figure

# %%
https://scikit-learn.org/stable/auto_examples/cluster/plot_kmeans_silhouette_analysis.html
